# %% [markdown]
# # Breast Cancer Winsconsin (BCW) Data Analysis
#
# This notebook will analyse and clean the **Breast Cancer Winsconsin Data** for best usage in the algorithms comparison. The data was extracted from the [UCI repository](https://archive.ics.uci.edu/ml/datasets/Breast+Cancer+Wisconsin+%28Diagnostic%29) which we can also find some data information.
#
# Now let's analyze, visualize and clean it.

# %% [markdown]
# ## Dependencies

# %%
# Define the root path
import os
import sys
path = os.getcwd().split('tests')[0]
# Import the necessary libraries
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
sns.set_style('darkgrid')
print(sns.__version__)
# Out:
# 0.11.1

# %%
names = ['ID','target']
attributes = ['radius','texture','perimeter','area','smooth','compact','concavity','concave_pts','symmetry','fractal_dim']
stats = ['mean','std','worst']

for i in range(len(stats)):
    for j in range(len(attributes)):
        names.append(attributes[j]+'_'+stats[i])

df = pd.read_csv(path+'/data/raw/wdbc.data',names=names)
df.head()
# Out:
#          ID target  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302      M        17.99         10.38          122.80     1001.0
# 1    842517      M        20.57         17.77          132.90     1326.0
# 2  84300903      M        19.69         21.25          130.00     1203.0
# 3  84348301      M        11.42         20.38           77.58      386.1
# 4  84358402      M        20.29         14.34          135.10     1297.0
#
#    smooth_mean  compact_mean  concavity_mean  concave_pts_mean  ...  \
# 0      0.11840       0.27760          0.3001           0.14710  ...
# 1      0.08474       0.07864          0.0869           0.07017  ...
# 2      0.10960       0.15990          0.1974           0.12790  ...
# 3      0.14250       0.28390          0.2414           0.10520  ...
# 4      0.10030       0.13280          0.1980           0.10430  ...
#
#    radius_worst  texture_worst  perimeter_worst  area_worst  smooth_worst  \
# ...

# %% [markdown]
# ## Samples and Attributes

# %%
print('Samples: {}'.format(df.shape[0]))
print('Attributes: {}'.format(df.shape[1]))
# Out:
# Samples: 569
# Attributes: 32

# %% [markdown]
# ## Let's analyze the information about the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
# ID                   569 non-null int64
# target               569 non-null object
# radius_mean          569 non-null float64
# texture_mean         569 non-null float64
# perimeter_mean       569 non-null float64
# area_mean            569 non-null float64
# smooth_mean          569 non-null float64
# compact_mean         569 non-null float64
# concavity_mean       569 non-null float64
# concave_pts_mean     569 non-null float64
# symmetry_mean        569 non-null float64
# fractal_dim_mean     569 non-null float64
# radius_std           569 non-null float64
# texture_std          569 non-null float64
# perimeter_std        569 non-null float64
# area_std             569 non-null float64
# smooth_std           569 non-null float64
# compact_std          569 non-null float64
# concavity_std        569 non-null float64
# concave_pts_std      569 non-null float64
# ...

# %% [markdown]
# Cool! There are no missing values and we have **30** functional attributes, **1** target column and **1** column for ID, in which we will drop in the future. So we have 10 attributes, which were calculated the mean, the standard deviation and trhe worst value. So for column 3-12 we have mean, 13 to 22 we have the standard deviation of the attributes, and finally 23 to 32 we have the wors values. So the features are:
#
# ### Numerical Features:
# * `radius`: mean of distances from center to points on the perimeter
# * `texture`: standard deviation of gray-scale values
# * `perimeter`
# * `area`
# * `smoothness`: local variation in radius lengths
# * `compactness`: perimeter^2 / area - 1.0
# * `concavity`: severity of concave portions of the contour
# * `concave points`: number of concave portions of the contour
# * `symmetry`
# * `fractal dimension`: "coastline approximation" - 1
#
# ### Categorical Feature
# * `target`: types of cancer (M-malignant,B-benign)

# %% [markdown]
# ## Let's analyze some data description

# %%
df.describe()
# Out:
#                  ID  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smooth_mean  compact_mean  concavity_mean  concave_pts_mean  \
# count   569.000000    569.000000      569.000000        569.000000
# mean      0.096360      0.104341        0.088799          0.048919
# std       0.014064      0.052813        0.079720          0.038803
# ...

# %% [markdown]
# We will now drop the ID column.

# %%
df = df.drop(['ID'],axis=1)

# %%
df.head()
# Out:
#   target  radius_mean  texture_mean  perimeter_mean  area_mean  smooth_mean  \
# 0      M        17.99         10.38          122.80     1001.0      0.11840
# 1      M        20.57         17.77          132.90     1326.0      0.08474
# 2      M        19.69         21.25          130.00     1203.0      0.10960
# 3      M        11.42         20.38           77.58      386.1      0.14250
# 4      M        20.29         14.34          135.10     1297.0      0.10030
#
#    compact_mean  concavity_mean  concave_pts_mean  symmetry_mean  ...  \
# 0       0.27760          0.3001           0.14710         0.2419  ...
# 1       0.07864          0.0869           0.07017         0.1812  ...
# 2       0.15990          0.1974           0.12790         0.2069  ...
# 3       0.28390          0.2414           0.10520         0.2597  ...
# 4       0.13280          0.1980           0.10430         0.1809  ...
#
#    radius_worst  texture_worst  perimeter_worst  area_worst  smooth_worst  \
# ...

# %% [markdown]
# Now we will analyze if there are duplicated values.

# %% [markdown]
# ## Duplicated Values

# %%
duplicates = df.duplicated()

# %%
duplicates.value_counts()
# Out:
# False    569
# dtype: int64

# %% [markdown]
# Cool! There are no duplicated values. Now we will transform the target dataset.

# %%
df = df.replace({'target':{'M':1,'B':2}})
df.head()
# Out:
#    target  radius_mean  texture_mean  perimeter_mean  area_mean  smooth_mean  \
# 0       1        17.99         10.38          122.80     1001.0      0.11840
# 1       1        20.57         17.77          132.90     1326.0      0.08474
# 2       1        19.69         21.25          130.00     1203.0      0.10960
# 3       1        11.42         20.38           77.58      386.1      0.14250
# 4       1        20.29         14.34          135.10     1297.0      0.10030
#
#    compact_mean  concavity_mean  concave_pts_mean  symmetry_mean  ...  \
# 0       0.27760          0.3001           0.14710         0.2419  ...
# 1       0.07864          0.0869           0.07017         0.1812  ...
# 2       0.15990          0.1974           0.12790         0.2069  ...
# 3       0.28390          0.2414           0.10520         0.2597  ...
# 4       0.13280          0.1980           0.10430         0.1809  ...
#
#    radius_worst  texture_worst  perimeter_worst  area_worst  smooth_worst  \
# ...

# %% [markdown]
# ## Data Visualization

# %% [markdown]
#  First we will visualize the boxplot and the barplot of the attributes, so we can see if the distributions are to high, if so we must scale our dataset.

# %%
new_names = names[1:]

plt.figure(figsize=(16,8))
ax = sns.boxplot(x='variable',y='value',data=pd.melt(df[new_names]))
ax.set_xticklabels(ax.get_xticklabels(),rotation=30);

# %%
fig, ax = plt.subplots(figsize=(16,8))
ax = sns.barplot(x='variable',y='value',data=pd.melt(df[new_names]),ax=ax)
ax.set_xticklabels(ax.get_xticklabels(),rotation=30);

# %% [markdown]
# We can see that the attributes `area_mean` and `area_worst` has values that are higher than others attributes, besides they have several outliers. So we must scale the dataset.

# %%
iqr = df[df.columns.values[1:]].quantile(0.75) - df[df.columns.values[1:]].quantile(0.25)
iqr
# Out:
# radius_mean            4.080000
# texture_mean           5.630000
# perimeter_mean        28.930000
# area_mean            362.400000
# smooth_mean            0.018930
# compact_mean           0.065480
# concavity_mean         0.101140
# concave_pts_mean       0.053690
# symmetry_mean          0.033800
# fractal_dim_mean       0.008420
# radius_std             0.246500
# texture_std            0.640100
# perimeter_std          1.751000
# area_std              27.340000
# smooth_std             0.002977
# compact_std            0.019370
# concavity_std          0.026960
# concave_pts_std        0.007072
# symmetry_std           0.008320
# fractal_dim_std        0.002310
# radius_worst           5.780000
# texture_worst          8.640000
# perimeter_worst       41.290000
# area_worst           568.700000
# smooth_worst           0.029400
# compact_worst          0.191900
# concavity_worst        0.268400
# concave_pts_worst      0.096470
# symmetry_worst         0.067500
# ...

# %% [markdown]
# But before we scale it, we will analyze some distributions and the correlation between the data.

# %%
df.shape
# Out:
# (569, 31)

# %%
fig, axes = plt.subplots(6,5,figsize=(20,12))
for i in range(30):
    j = i+1
    r = int(abs(i/5))
    c = int(i-5*r)
    g = sns.histplot(df,x=new_names[j], palette="coolwarm",ax=axes[r,c])
    g.set_ylabel('')
    g.set_xlabel('')

# %% [markdown]
# We can see that the distributions are not all normal distributed and there are some with wight **skewness** and **kurtosis**, so let's measure them.

# %%
skew = df.skew()
skew.loc[skew > 1].sort_values(ascending=False)
# Out:
# area_std             5.447186
# concavity_std        5.110463
# fractal_dim_std      3.923969
# perimeter_std        3.443615
# radius_std           3.088612
# smooth_std           2.314450
# symmetry_std         2.195133
# compact_std          1.902221
# area_worst           1.859373
# fractal_dim_worst    1.662579
# texture_std          1.646444
# area_mean            1.645732
# compact_worst        1.473555
# concave_pts_std      1.444678
# symmetry_worst       1.433928
# concavity_mean       1.401180
# fractal_dim_mean     1.304489
# compact_mean         1.190123
# concave_pts_mean     1.171180
# concavity_worst      1.150237
# perimeter_worst      1.128164
# radius_worst         1.103115
# dtype: float64

# %%
print("How many columns with high skewness shifted to left: ", skew.loc[skew > 1].size)
# Out:
# How many columns with high skewness shifted to left:  22

# %%
skew.loc[skew<-1].sort_values()
# Out:
# Series([], dtype: float64)

# %%
print("How many columns with high skewness shifted to right: ", skew.loc[skew < -1].size)
# Out:
# How many columns with high skewness shifted to right:  0

# %%
df_log10 = np.log10(1+df[df.columns.values[1:]])
df_log10.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smooth_mean  \
# 0     1.278525      1.056142        2.092721   3.000868     0.048597
# 1     1.333850      1.273464        2.126781   3.122871     0.035326
# 2     1.315760      1.347330        2.117271   3.080626     0.045166
# 3     1.094122      1.330008        1.895312   2.587823     0.057856
# 4     1.328176      1.185825        2.133858   3.113275     0.041511
#
#    compact_mean  concavity_mean  concave_pts_mean  symmetry_mean  \
# 0      0.106395        0.113977          0.059601       0.094087
# 1      0.032877        0.036190          0.029453       0.072323
# 2      0.064421        0.078239          0.052271       0.081671
# 3      0.108531        0.093912          0.043441       0.100267
# 4      0.054153        0.078457          0.043087       0.072213
#
#    fractal_dim_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0          0.032905  ...      1.421275       1.263162         2.268578
# ...

# %%
# Let's plot the distribution

fig, axes = plt.subplots(6,5,figsize=(20,12))
for i in range(30):
    j = i+1
    r = int(abs(i/5))
    c = int(i-5*r)
    g = sns.histplot(df_log10,x=new_names[j], palette="coolwarm",ax=axes[r,c])
    g.set_ylabel('')
    g.set_xlabel('')

# %% [markdown]
# Let's see the skewness

# %%
skew_10 = df_log10.skew()
skew_10.loc[skew_10>1]
# Out:
# compact_mean         1.043195
# concavity_mean       1.206982
# concave_pts_mean     1.083180
# fractal_dim_mean     1.272294
# radius_std           1.713417
# perimeter_std        1.025375
# smooth_std           2.283394
# compact_std          1.816278
# concavity_std        4.231738
# concave_pts_std      1.399869
# symmetry_std         2.135874
# fractal_dim_std      3.874373
# compact_worst        1.048729
# symmetry_worst       1.152984
# fractal_dim_worst    1.558559
# dtype: float64

# %%
print("Skewness shifted to the left: ",skew_10.loc[skew_10>1].size)
# Out:
# Skewness shifted to the left:  15

# %%
print("Skewness shifted to the right: ",skew_10.loc[skew_10<-1].size)
# Out:
# Skewness shifted to the right:  0

# %% [markdown]
# Definitely the number of shifted attributes has decreased from **22** to **15**, but still is to high.
# Now we will see the boxplot of the log transformed data, then we will tray to scale the original data.

# %%
plt.figure(figsize=(16,8))
ax = sns.boxplot(x='variable',y='value',data=pd.melt(df_log10))
ax.set_xticklabels(ax.get_xticklabels(),rotation=30);

# %%
new_names = df_log10.columns.values
iqr_10 = df_log10.quantile(0.75)-df_log10.quantile(0.25)
for i in range(len(new_names)):
    df_vals = df_log10[(df_log10[new_names[i]]<df_log10[new_names[i]].quantile(0.25)-1.5*iqr_10[i])|(df_log10[new_names[i]]>df_log10[new_names[i]].quantile(0.75)+1.5*iqr_10[i])]
    print("Outliers for {}: {}".format(new_names[i],df_vals.shape[0]))
# Out:
# Outliers for radius_mean: 7
# Outliers for texture_mean: 2
# Outliers for perimeter_mean: 6
# Outliers for area_mean: 5
# Outliers for smooth_mean: 6
# Outliers for compact_mean: 15
# Outliers for concavity_mean: 14
# Outliers for concave_pts_mean: 8
# Outliers for symmetry_mean: 15
# Outliers for fractal_dim_mean: 15
# Outliers for radius_std: 31
# Outliers for texture_std: 9
# Outliers for perimeter_std: 13
# Outliers for area_std: 7
# Outliers for smooth_std: 29
# Outliers for compact_std: 26
# Outliers for concavity_std: 22
# Outliers for concave_pts_std: 18
# Outliers for symmetry_std: 27
# Outliers for fractal_dim_std: 28
# Outliers for radius_worst: 4
# Outliers for texture_worst: 2
# Outliers for perimeter_worst: 2
# Outliers for area_worst: 2
# Outliers for smooth_worst: 5
# Outliers for compact_worst: 12
# Outliers for concavity_worst: 5
# Outliers for concave_pts_worst: 0
# Outliers for symmetry_worst: 20
# Outliers for fractal_dim_worst: 23

# %% [markdown]
# Let's Scale the Data

# %%
cols = df.columns.values

scale = StandardScaler()

X = scale.fit_transform(df_log10[cols[1:]])

df_scale = pd.DataFrame(columns=cols)
df_scale = pd.concat([df['target'],pd.DataFrame(X,columns=cols[1:])],axis=1)

# %%
plt.figure(figsize=(16,8))
ax = sns.boxplot(x='variable',y='value',data=pd.melt(df_scale[df_scale.columns.values[1:]]))
ax.set_xticklabels(ax.get_xticklabels(),rotation=30);

# %% [markdown]
# We can see that there are several outliers!

# %%
cols = df_scale.columns.values
iqr_scale = df_scale.quantile(0.75)-df_scale.quantile(0.25)
df_out = pd.DataFrame(columns=['Attribute','Outliers'])
for i in range(len(cols)-1):
    df_outliers = df_scale[(df_scale[cols[i+1]]<df_scale[cols[i+1]].quantile(0.25)-1.5*iqr_scale[cols[i+1]])|
                      (df_scale[cols[i+1]]>df_scale[cols[i+1]].quantile(0.75)+1.5*iqr_scale[cols[i+1]])]
    df_out=df_out.append(pd.DataFrame([[cols[i+1],df_outliers.shape[0]]], columns=['Attribute','Outliers']))
df_out.sort_values(by='Outliers',ascending=False)
# Out:
#            Attribute Outliers
# 0         radius_std       31
# 0         smooth_std       29
# 0    fractal_dim_std       28
# 0       symmetry_std       27
# 0        compact_std       26
# 0  fractal_dim_worst       23
# 0      concavity_std       22
# 0     symmetry_worst       20
# 0    concave_pts_std       18
# 0      symmetry_mean       15
# 0   fractal_dim_mean       15
# 0       compact_mean       15
# 0     concavity_mean       14
# 0      perimeter_std       13
# 0      compact_worst       12
# 0        texture_std        9
# 0   concave_pts_mean        8
# 0        radius_mean        7
# 0           area_std        7
# 0     perimeter_mean        6
# 0        smooth_mean        6
# 0       smooth_worst        5
# 0    concavity_worst        5
# 0          area_mean        5
# 0       radius_worst        4
# 0       texture_mean        2
# 0      texture_worst        2
# 0    perimeter_worst        2
# 0         area_worst        2
# 0  concave_pts_worst        0

# %%
# Let's see the data influence
pca = PCA()
x_pca = pca.fit_transform(df_scale[df_scale.columns.values[1:]])

var = pca.explained_variance_ratio_
cols = ['target']
cols = cols + ["PC" + str(i+1) for i in range(30)]
df_pca = pd.DataFrame(columns=cols)
df_pca = pd.concat([df_scale['target'],pd.DataFrame(x_pca,columns=["PC" + str(i+1) for i in range(30)])],axis=1)
df_pca
# Out:
#      target        PC1       PC2       PC3       PC4       PC5       PC6  \
# 0         1   8.745586  2.141451 -1.907386 -3.456889 -1.776053  1.386106
# 1         1   2.497443 -3.760404 -0.325568 -1.160900  0.210882  0.029769
# 2         1   5.956195 -1.105471 -0.399887 -0.829275 -0.537001  0.498242
# 3         1   6.978574  9.783296 -3.358459  0.979157 -2.592354  2.877232
# 4         1   4.069375 -1.802357  1.130871 -3.518561 -0.167019 -1.292270
# 5         1   2.631249  3.610446 -3.234273 -0.172838 -1.067754 -0.415609
# 6         1   2.596294 -2.943058 -1.311286  0.062103 -0.158732 -0.167197
# 7         1   2.673030  2.061152 -0.740611  0.644920 -1.389649 -1.226029
# 8         1   3.432837  3.016065 -3.052068  1.396061 -1.307279  0.523153
# 9         1   6.120897  7.038249 -3.934861  3.392238  2.367911 -0.537506
# 10        1  -0.407589 -3.019041  0.087947  1.575896  0.422843  0.152149
# 11        1   3.164152 -0.323301 -1.293597  0.143999  0.197007  0.758007
# ...

# %%
fig, axes = plt.subplots(6,5,figsize=(20,15))
for i in range(df_scale.columns.values[1:].size):
    r = int(i/5)
    c = int(i-5*r)
    g = sns.histplot(data=df_scale,x=df_scale.columns.values[i+1],palette='coolwarm',ax=axes[r,c])
    g.set_xlabel('')
    g.set_ylabel('')

# %%
skew_scale = df_scale.skew()

# %%
skew_scale[skew_scale > 1].sort_values(ascending=False)
# Out:
# area_std             5.447186
# concavity_std        5.110463
# fractal_dim_std      3.923969
# perimeter_std        3.443615
# radius_std           3.088612
# smooth_std           2.314450
# symmetry_std         2.195133
# compact_std          1.902221
# area_worst           1.859373
# fractal_dim_worst    1.662579
# texture_std          1.646444
# area_mean            1.645732
# compact_worst        1.473555
# concave_pts_std      1.444678
# symmetry_worst       1.433928
# concavity_mean       1.401180
# fractal_dim_mean     1.304489
# compact_mean         1.190123
# concave_pts_mean     1.171180
# concavity_worst      1.150237
# perimeter_worst      1.128164
# radius_worst         1.103115
# dtype: float64

# %%
skew_scale[skew_scale > 1].size
# Out:
# 22

# %% [markdown]
# Accent, Accent_r, Blues, Blues_r, BrBG, BrBG_r, BuGn, BuGn_r, BuPu, BuPu_r, CMRmap, CMRmap_r, Dark2, Dark2_r, GnBu, GnBu_r, Greens, Greens_r, Greys, Greys_r, OrRd, OrRd_r, Oranges, Oranges_r, PRGn, PRGn_r, Paired, Paired_r, Pastel1, Pastel1_r, Pastel2, Pastel2_r, PiYG, PiYG_r, PuBu, PuBuGn, PuBuGn_r, PuBu_r, PuOr, PuOr_r, PuRd, PuRd_r, Purples, Purples_r, RdBu, RdBu_r, RdGy, RdGy_r, RdPu, RdPu_r, RdYlBu, RdYlBu_r, RdYlGn, RdYlGn_r, Reds, Reds_r, Set1, Set1_r, Set2, Set2_r, Set3, Set3_r, Spectral, Spectral_r, Wistia, Wistia_r, YlGn, YlGnBu, YlGnBu_r, YlGn_r, YlOrBr, YlOrBr_r, YlOrRd, YlOrRd_r, afmhot, afmhot_r, autumn, autumn_r, binary, binary_r, bone, bone_r, brg, brg_r, bwr, bwr_r, cividis, cividis_r, cool, cool_r, coolwarm, coolwarm_r, copper, copper_r, crest, crest_r, cubehelix, cubehelix_r, flag, flag_r, flare, flare_r, gist_earth, gist_earth_r, gist_gray, gist_gray_r, gist_heat, gist_heat_r, gist_ncar, gist_ncar_r, gist_rainbow, gist_rainbow_r, gist_stern, gist_stern_r, gist_yarg, gist_yarg_r, gnuplot, gnuplot2, gnuplot2_r, gnuplot_r, gray, gray_r, hot, hot_r, hsv, hsv_r, icefire, icefire_r, inferno, inferno_r, jet, jet_r, magma, magma_r, mako, mako_r, nipy_spectral, nipy_spectral_r, ocean, ocean_r, pink, pink_r, plasma, plasma_r, prism, prism_r, rainbow, rainbow_r, rocket, rocket_r, seismic, seismic_r, spring, spring_r, summer, summer_r, tab10, tab10_r, tab20, tab20_r, tab20b, tab20b_r, tab20c, tab20c_r, terrain, terrain_r, twilight, twilight_r, twilight_shifted, twilight_shifted_r, viridis, viridis_r, vlag, vlag_r, winter, winter_r

# %%
fig, axes = plt.subplots(6,5,figsize=(20,12))
for i in range(30):
    j = i+1
    r = int(abs(i/5))
    c = int(i-5*r)
    g = sns.kdeplot(data=df,x=new_names[j],hue=new_names[0],fill=True, common_norm=False, palette="coolwarm",
   alpha=.7, linewidth=0,ax=axes[r,c])
    g.set_ylabel('')
    g.set_xlabel('')
